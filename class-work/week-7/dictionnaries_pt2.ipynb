# %% [markdown]
# # Dictionnaries pt 2
#
# Test March 8: Pandas (Matplotlib, Numpy), Debugging, Nested Loops, Tuples, 2D Lists, Time Complexity, and Dictionnaries

# %%
# Question 1
tup = ('grape', 33.12, [98, 99], 'apricot')
lst = tup[2]
tup[2][0] = 77
lst.append('tomato')
print(tup)
print(lst)
# Out:
# ('grape', 33.12, [77, 99, 'tomato'], 'apricot')
# [77, 99, 'tomato']

# %% [markdown]
# Question 2:
#
# - A. `d = {'a': 3, 'b': 6, 'c': 8}`
# - B. `d = {('a', 1): 'hello', ('b', 2): 'world'}`
# - C. `d = {['a', 1]: 'hello', ['b', 2]: 'world'}` this is the only one that's not circled
# - D. `d = {'monarch': 5, 'bronze copper': 7, 'monarch': 7}`
# - E. `d = {3: [8, 6], 4: [10, 12], 6: [1, 1]}`

# %%
# Question 3

# fabio's answer
def capital(dict_countries):
    if 'Madagascar' not in dict_countries.keys():
        dict_countries['Madagascar'] = 'Antananarivo'
    print(list(dict_countries.keys()))

dict_countries1 = {'Canada': 'Ottawa', 'Japan': 'Tokyo', 'Madagascar': 'Antananarivo'}
capital(dict_countries1)

# teacher answer
def capitals(d):
    d['Madagascar'] = d.get('Madagascar', 'Antananarivo')
    print(list(d.keys()))

capitals(dict_countries1)
# Out:
# ['Canada', 'Japan', 'Madagascar']
# ['Canada', 'Japan', 'Madagascar']
