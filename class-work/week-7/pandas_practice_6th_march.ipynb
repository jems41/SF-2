# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Student_Grades.csv')
balls = df.to_numpy() # useful to get something using normal python
df.T # swaps rows and columns axis
df.sort_index(axis=1, ascending=True) # sort by columns
df.sort_values(by='Scores') # sort by values in a column

df[['Scores']]
df.loc[:, ['Scores']]
df.iloc[:, [5]]
df.loc[1:10, ['Scores']]

item = df.loc[0, 'Scores']
for i in range(1, len(df)):
    if df.loc[i, 'Scores'] > item:
        item = df.loc[i, 'Scores']

df.iloc[[0], [0]]
df.iat[0, 0]

df[df['Scores'] > 50]
df[(df['Scores'] > 50) & (df['Scores'] < 70)]

df2 = df.copy()
df2['Failed?'] = df2['Scores'] > 59
for i in range(len(df2['Failed?'])):
    item = df2.loc[i, 'Failed?']
    if item == False:
        df2.loc[i, 'Failed?'] = 'Failed'
        df2.loc[i, 'Grade'] = 'F'
    else:
        df2.loc[i, 'Failed?'] = 'Passed'

df2[df["Scores"].isin([20, 95])]
# Out:
# C:\Users\combj\AppData\Local\Temp\ipykernel_38736\2169442394.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Failed' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df2.loc[i, 'Failed?'] = 'Failed'
#     Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade Failed?
# 5     1.5       0.2       0.0      2.0        2.2    20.0     F  Failed
# 15    8.9       6.2       6.0      9.0        9.7    95.0     A  Passed
